# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re

# %%
#Offense Ranks 2021

url = 'https://www.sports-reference.com/cfb/years/2021-team-offense.html'
year=2021

r=requests.get(url)
soup=bs(r.content)
table = soup.select('table.sortable stats_table now_sortable is_sorted.tr data-row')
table=soup.find_all('table')
df1=pd.read_html(str(table))[0]

#del df1['Rk']
#del df1['Notes']

df1['Year'] = year
df1
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk             School                  G
# 0                    1         Ohio State                 13
# 1                    2   Western Kentucky                 14
# 2                    3               Pitt                 14
# 3                    4        Wake Forest                 14
# 4                    5   Coastal Carolina                 13
# ..                 ...                ...                ...
# 137                126      Massachusetts                 12
# 138                127             Temple                 12
# 139                128         Vanderbilt                 12
# 140                129        Connecticut                 12
# 141                130         New Mexico                 12
#
#     Unnamed: 3_level_0 Passing                         Rushing  ...  \
#                    Pts     Cmp   Att   Pct    Yds   TD     Att  ...
# 0                 45.7    26.8  38.0  70.6  380.9  3.5    32.3  ...
# 1                 44.2    34.3  49.8  68.9  433.7  4.5    24.8  ...
# 2                 41.4    26.2  38.8  67.6  337.4  3.1    37.3  ...
# 3                 41.0    21.6  37.1  58.2  307.4  2.8    40.4  ...
# 4                 40.9    17.5  24.8  70.5  265.9  2.5    38.8  ...
# ..                 ...     ...   ...   ...    ...  ...     ...  ...
# 137               16.3    13.6  27.7  49.1  153.1  0.9    34.6  ...
# 138               16.3    17.8  30.3  58.8  177.9  0.8    29.9  ...
# 139               15.8    18.8  34.1  55.3  189.3  1.1    35.3  ...
# 140               15.6    17.3  33.9  51.1  163.8  0.9    31.3  ...
# 141               12.2    11.9  21.7  55.0  114.1  0.8    38.4  ...
#
#     First Downs                  Penalties       Turnovers            Year
#            Pass  Rush  Pen   Tot       No.   Yds       Fum  Int  Tot
# 0          16.5   9.0  1.2  26.8       6.5  59.2       0.2  0.6  0.8  2021
# 1          18.9   6.7  2.0  27.6       6.8  54.1       0.6  0.9  1.5  2021
# 2          14.9   9.1  1.9  25.9       6.7  63.9       0.5  0.6  1.1  2021
# 3          13.8   8.3  3.2  25.3       5.8  52.7       0.4  1.1  1.4  2021
# 4          11.2  11.8  0.8  23.8       5.4  50.8       0.5  0.3  0.8  2021
# ..          ...   ...  ...   ...       ...   ...       ...  ...  ...   ...
# 137         6.9   7.4  2.0  16.3       6.3  61.2       0.8  0.9  1.7  2021
# 138         7.3   6.2  1.3  14.8       5.8  44.0       0.9  0.8  1.7  2021
# 139         8.7   7.0  1.9  17.6       5.5  44.0       0.4  1.2  1.6  2021
# 140         6.6   5.9  2.1  14.6       6.8  49.2       0.4  1.4  1.8  2021
# 141         4.9   7.3  1.7  13.8       6.9  57.1       1.0  0.7  1.7  2021
#
# [142 rows x 26 columns]
